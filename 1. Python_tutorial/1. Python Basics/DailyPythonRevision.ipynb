# %% [markdown]
# # ChatGPT Prompt
# Daily Python Interview Drill:
# Ask me 50 short easy problems (for fluency) covering ALL Python basics
# (lists, slicing, methods, strings, dicts, sets, loops, comprehensions,
# functions, *args, **kwargs, file I/O, exceptions, OOP, plotting).
# One at a time.
# After I answer, say correct/wrong + 1 sentence explanation.
# Continue until all 50 are done.

# %% [markdown]
# # 🧠 Python Daily Mastery Tracker
# Track your comfort level daily and auto-generate targeted drills.
# Comfort Scale:
# 0 = No idea, 1 = weak, 2 = improving, 3 = OK, 4 = strong, 5 = fluent/interview-ready

# %% [markdown]
# ## 📅 Date: 2025-11-29
#
# ### 📌 Core Python Fundamentals
# | Topic | Comfort (0–5) | Notes |
# |-------|----------------|--------|
# | Lists | 4 | solid |
# | Slicing | 3 | boundary mistakes |
# | List Comprehensions | 5 | fluent |
# | Loops | 4 | |
# | Strings | 4 | |
#
# ### 📌 Intermediate
# | Topic | Comfort (0–5) | Notes |
# |-------|----------------|--------|
# | Dictionaries | 2 | need `.get()` logic |
# | Dict Comprehensions | 2 | syntax confusion |
# | Sets | ? | not tested |
# | File I/O | 4 | |
# | Exceptions | 3 | bare vs specific |
# | print() behavior | 2 | tuples confusion |
#
# ### 📌 Functions & Arguments
# | Topic | Comfort (0–5) | Notes |
# |-------|----------------|--------|
# | Functions | 4 | |
# | Lambda | 1 | uncomfortable |
# | *args/**kwargs | ? | |
#
# ### 📌 Higher Level Python
# | Topic | Comfort (0–5) | Notes |
# |-------|----------------|--------|
# | OOP | ? | |
# | Plotting | ? | |

# %%
# Update this dictionary daily
scores = {
    "Lists": 4,
    "Slicing": 3,
    "List Comprehensions": 5,
    "Loops": 4,
    "Strings": 4,
    "Dictionaries": 2,
    "Dict Comprehensions": 2,
    "Sets": 0,
    "File I/O": 2,
    "Exceptions": 3,
    "print() behavior": 2,
    "Functions": 4,
    "Lambda": 1,
    "*args/**kwargs": 0,
    "OOP": 0,
    "Plotting": 0,
}

# Identify weak topics (anything <4)
weak_topics = [topic for topic, score in scores.items() if (score is not None and score < 4)]
weak_topics
# Out:
# ['Slicing',
#  'Dictionaries',
#  'Dict Comprehensions',
#  'Sets',
#  'File I/O',
#  'Exceptions',
#  'print() behavior',
#  'Lambda',
#  '*args/**kwargs',
#  'OOP',
#  'Plotting']
