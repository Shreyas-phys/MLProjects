# %% [markdown]
# I want to begin the Python + NumPy Fluency Training for my first 300 problems. Give me exactly one very short, simple coding question at a time, solvable in 1–5 lines, focusing only on fluency—not difficult logic. Rotate through Python basics (variables, lists, slicing, loops, list comprehensions, functions, strings, dictionaries, file I/O, basic classes, simple exceptions) and especially NumPy foundations (array creation, indexing, slicing, boolean masks, broadcasting, reshaping, vectorization, simple math operations, stacking/splitting, debugging small errors). After each question, wait for me to paste my solution. Then give detailed, critical feedback: explain what each line does, point out mistakes, inefficiencies, misunderstandings, shape issues, dtype issues, or conceptual gaps, and tell me my weak spots. Keep questions extremely small and clear; the goal is to make Python + NumPy second nature. After giving feedback, ask me if I want the next question. Do not give solutions unless I ask.
